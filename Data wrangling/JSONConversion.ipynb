# %%
import pandas as pd

# %%
# !ls csv_generation/
# Out:
# merged_movie_data.csv          merged_movie_data_success.csv
# merged_movie_data2.csv         merged_movie_data_success2.csv
# merged_movie_data3.csv         merged_movie_data_success3.csv
# merged_movie_data4.csv         merged_movie_data_success4.csv
# merged_movie_data5.csv         merged_movie_data_success5.csv

# %%
df = pd.read_csv("csv_generation/merged_movie_data_success2.csv")
print(df.columns)
df[["Title","Director", "Genre", "Plot", "imdbRating", "imdbVotes","Poster"]]
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'Title', 'Year',
#        'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors',
#        'Plot', 'Language', 'Country', 'Awards', 'Poster', 'Ratings',
#        'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'DVD',
#        'BoxOffice', 'Production', 'Website', 'Response', 'totalSeasons'],
#       dtype='object')
#                Title            Director                     Genre  \
# ...

# %%
keep_columns = ["Title", "Director", "Genre", "Plot", "imdbRating", "imdbVotes", "Poster"]

merged_df = pd.DataFrame(columns=keep_columns)

for infile_name in ["csv_generation/merged_movie_data_success.csv", "csv_generation/merged_movie_data_success2.csv", "csv_generation/merged_movie_data_success3.csv", "csv_generation/merged_movie_data_success4.csv", "csv_generation/merged_movie_data_success5.csv"]:
    infile = pd.read_csv(infile_name, usecols=keep_columns)
    merged_df = pd.concat([merged_df, infile])

merged_df.drop_duplicates(inplace=True)
merged_df.dropna(subset=["Plot"], inplace=True)

merged_df.to_csv("final_5k_movies_data.csv", index=False)
merged_df.to_json("merged_movie_data.json", orient="records")

# %%
pd.read_csv("final_5k_movies_data.csv")
# Out:
#                                        Title  \
# 0                                    Spectre
# 1                               Spider-Man 3
# 2                    Avengers: Age of Ultron
# 3     Harry Potter and the Half-Blood Prince
# 4         Batman v Superman: Dawn of Justice
# ...                                      ...
# 4085                      The Act of Killing
# 4086                   Taxi to the Dark Side
# 4087               Antarctica: A Year on Ice
# 4088                                Hardflip
# 4089            Chocolate: Deep Dark Secrets
#
#                                            Director  \
# 0                                        Sam Mendes
# 1                                         Sam Raimi
# 2                                       Joss Whedon
# 3                                       David Yates
# 4                                       Zack Snyder
# ...                                             ...
# ...

# %%
pd.read_json("merged_movie_data.json")
# Out:
#                                        Title  \
# 0                                    Spectre
# 1                               Spider-Man 3
# 2                    Avengers: Age of Ultron
# 3     Harry Potter and the Half-Blood Prince
# 4         Batman v Superman: Dawn of Justice
# ...                                      ...
# 4085                      The Act of Killing
# 4086                   Taxi to the Dark Side
# 4087               Antarctica: A Year on Ice
# 4088                                Hardflip
# 4089            Chocolate: Deep Dark Secrets
#
#                                            Director  \
# 0                                        Sam Mendes
# 1                                         Sam Raimi
# 2                                       Joss Whedon
# 3                                       David Yates
# 4                                       Zack Snyder
# ...                                             ...
# ...

# %%
# !cat merged_movie_data.json
# Out:
# [{"Title":"Spectre","Director":"Sam Mendes","Genre":"Action, Adventure, Thriller","Plot":"A cryptic message from the past sends James Bond (Daniel Craig) on a rogue mission to Mexico City and eventually Rome, where he meets Lucia Sciarra (Monica Belluci), the beautiful and forbidden widow of an infamous criminal. Bond infiltrates a secret meeting and uncovers the existence of the sinister organisation known as S.P.E.C.T.R.E. Meanwhile, back in London, Max Denbigh (Andrew Scott), the new head of the Centre of National Security, questions Bond's actions and challenges the relevance of MI6, led by M (Ralph Fiennes). Bond covertly enlists Miss Eve Moneypenny (Naomie Harris) and Q (Ben Whishaw) to help him seek out Dr. Madeleine Swann (L\u00e9a Seydoux), the daughter of his old nemesis Mr. White (Jesper Christensen), who may hold the clue to untangling the web of S.P.E.C.T.R.E. As the daughter of the assassin, she understands Bond in a way most others cannot. As Bond ventures towards the 
# ...
